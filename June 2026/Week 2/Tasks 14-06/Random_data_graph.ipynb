# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randint(1,100,10)
print(data)

plt.plot(range(1,11), data)
plt.title("Random Graph")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()
# Out:
# [ 4  3 32 43 17 18 14 72 26 69]
