# %%
import numpy as np
import matplotlib.pyplot as plt

sales = np.array([25000,35000,45000,55000,65000])

print("Mean:", np.mean(sales))
print("Median:", np.median(sales))
print("Standard Deviation:", np.std(sales))

months = ["Jan", "Feb", "Mar", "Apr", "May"]

plt.bar(months, sales)
plt.title("Sales Chart Months x Sales")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.show()
# Out:
# Mean: 45000.0
# Median: 45000.0
# Standard Deviation: 14142.13562373095
